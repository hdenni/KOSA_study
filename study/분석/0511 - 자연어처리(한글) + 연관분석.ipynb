# %% [markdown]
# ## 한글 자연어 처리

# %% [markdown]
# ### Hannanum

# %%
from konlpy.tag import Hannanum

# %%
han = Hannanum()

# %%
text = "아버지가 방에 들어가신다"

# %%
han.nouns(text)
# Out:
# ['아버지', '방']

# %%
han.pos(text)
# Out:
# [('아버지', 'N'),
#  ('가', 'J'),
#  ('방', 'N'),
#  ('에', 'J'),
#  ('들', 'P'),
#  ('어', 'E'),
#  ('가', 'P'),
#  ('시ㄴ다', 'E')]

# %%
text = u"아름답지만 다소 복잡하기도한 한국어는 전세계에서 13번째로 많이 사용되는 언어입니다."

# %%
han.nouns(text)
# Out:
# ['복잡하기도한', '한국어', '전세계', '13번', '사용', '언어']

# %%
han.pos(text)
# Out:
# [('아름답', 'P'),
#  ('지만', 'E'),
#  ('다소', 'M'),
#  ('복잡하기도한', 'N'),
#  ('한국어', 'N'),
#  ('는', 'J'),
#  ('전세계', 'N'),
#  ('에서', 'J'),
#  ('13번', 'N'),
#  ('째', 'X'),
#  ('로', 'J'),
#  ('많', 'P'),
#  ('이', 'X'),
#  ('사용', 'N'),
#  ('되', 'X'),
#  ('는', 'E'),
#  ('언어', 'N'),
#  ('이', 'J'),
#  ('ㅂ니다', 'E'),
#  ('.', 'S')]

# %%
han.pos(text, ntags=22)
# Out:
# [('아름답', 'PA'),
#  ('지만', 'EC'),
#  ('다소', 'MA'),
#  ('복잡하기도한', 'NC'),
#  ('한국어', 'NC'),
#  ('는', 'JX'),
#  ('전세계', 'NC'),
#  ('에서', 'JC'),
#  ('13', 'NN'),
#  ('번', 'NB'),
#  ('째', 'XS'),
#  ('로', 'JC'),
#  ('많', 'PA'),
#  ('이', 'XS'),
#  ('사용', 'NC'),
#  ('되', 'XS'),
#  ('는', 'ET'),
#  ('언어', 'NC'),
#  ('이', 'JP'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF')]

# %% [markdown]
# ### Kkma

# %%
from konlpy.tag import Kkma

# %%
kkma = Kkma()

# %%
kkma.nouns(text)
# Out:
# ['복잡', '한국어', '전세계', '13', '13번째', '번째', '사용', '언어']

# %%
from konlpy.tag import Komoran

# %%
kom = Komoran(userdic="./userdic.txt")

# %%
kom.nouns(text)
# Out:
# ['한국어', '전', '세계', '번', '사용', '언어']

# %%
text2 = "홍길동의 오픈소스"

# %%
kom.nouns(text2)
# Out:
# ['홍길동', '오픈', '소스']

# %%
kom.pos(text2)
# Out:
# [('홍길동', 'NNP'), ('의', 'JKG'), ('오픈', 'NNP'), ('소스', 'NNP')]

# %% [markdown]
# ### corpus

# %%
from konlpy.corpus import kolaw

# %%
c = kolaw.open("constitution.txt").read()

# %%
c[:100]
# Out:
# '대한민국헌법\n\n유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의'

# %%
from konlpy.corpus import kobill

# %%
b = kobill.open("1809890.txt").read()

# %%
b[:200]
# Out:
# '지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이사철․여상규․안규백\n\n황영철․박영아․김정훈\n\n김학송 의원(10인)\n\n제안이유 및 주요내용\n\n  초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요\n\n한 나이이나, 현재 '

# %% [markdown]
# ### Komoran

# %%
from wordcloud import WordCloud

# %%
from konlpy.tag import Komoran

# %%
komoran = Komoran()

# %%
word_list = komoran.nouns("%r"%c[:1000]) #r"\''""
# 개행, 역슬래시 등이 문장에 포함되어 있을 경우에 관한 예외처리

# %%
text = ' '.join(word_list)

# %%
text
# Out:
# '대한민국 헌법 유구 한 역사 전통 국민 운동 건립 대한민국 임시 정부 법통 불의 항거 민주 이념 계승 조국 민주개혁 평화 통일 사명 입각 정의 인도 동포애 민족 단결 사회 폐습 불의 타파 자율 조화 바탕 자유 민주 기본 질서 정치 경제 사회 문화 영역 각인 기회 능력 최고 도로 발휘 자유 권리 책임 의무 완수 안 국민 생활 균등 향상 밖 항구 세계 평화 인류 공영 이바지 우리들의 자손 안전 자유 행복 확보 것 다짐 년 7월 12일 제정 차 개정 헌법 국회 의결 국민 투표 개정 장 강 대한민국 민주공화국 대한민국 주권 국민 권력 국민 대한민국 국민 요건 법률 국가 법률 바 재외국민 보호 의무 대한민국 영토 한반도 부속 도서 대한민국 통일 지향 자유 민주 기본 질서 입각 평화 통일 정책 수립 추진 대한민국 국제 평화 유지 노력 침략 전쟁 부인 국군 국가 안전 보장 국토방위 신성 의무 수행 사명 정치 중립 준수 헌법 체결 공포 조약 일반 승인 국제 법규 국내법 효력 외국인 국제법 조약 바 지위 보장 공무원 국민 전체 봉사자 국민 책임 공무원 신분 정치 중립 법률 바 보장 정당 설립 자유 복수 정당'

# %%
wordc = WordCloud()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
wordc.generate(text)

plt.imshow(wordc)
plt.show()

# %% [markdown]
# ## font 설정

# %%
import matplotlib.font_manager as fm
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
font_list
# Out:
# ['C:\\Windows\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\SourceSansPro-Semibold.ttf',
#  'C:\\Windows\\Fonts\\upceb.ttf',
#  'C:\\Windows\\Fonts\\cordiauz.ttf',
#  'C:\\Windows\\Fonts\\browauz.ttf',
#  'C:\\Windows\\Fonts\\comic.ttf',
#  'C:\\Windows\\Fonts\\cordia.ttf',
#  'C:\\Windows\\Fonts\\verdanai.ttf',
#  'C:\\Windows\\Fonts\\mingliu.ttc',
#  'C:\\Windows\\Fonts\\kokilai.ttf',
#  'C:\\Windows\\Fonts\\tunga.ttf',
#  'C:\\Windows\\Fonts\\CENTURY.TTF',
#  'C:\\Windows\\Fonts\\NanumSquareRoundEB.ttf',
#  'C:\\Windows\\Fonts\\simpo.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareB.ttf',
#  'C:\\Windows\\Fonts\\HMFMMUEX.TTC',
#  'C:\\Windows\\Fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\rod.ttf',
#  'C:\\Windows\\Fonts\\browaub.ttf',
#  'C:\\Windows\\Fonts\\cordiaui.ttf',
#  'C:\\Windows\\Fonts\\Vani.ttf',
#  'C:\\Windows\\Fonts\\couri.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicCoding.ttf',
#  'C:\\Windows\\Fonts\\upcfi.ttf',
#  'C:\\Windows\\Fonts\\segoescb.ttf',
# ...

# %%
wordc = WordCloud(background_color='white', max_words=20,
                 font_path="C:/Windows/Fnts/NanumGothicCoding.ttf",
                 relative_scaling=0.2)

# %%
from konlpy.tag import Komoran
komoran = Komoran()

# %%
word_list = komoran.nouns("%r"%c)
len(word_list)
# Out:
# 3361

# %%
plt.imshow(wordc)
plt.axis('off')
plt.show()

# %%
data = kolaw.open('constitution.txt').read()
komoran = Komoran()
word_list2 = komoran.nouns("%r"%data)
wordcloud = WordCloud(background_color='black', max_words=2000,
                 font_path="C:/Windows/Fnts/NanumGothicCoding.ttf",
                 relative_scaling=0.2)
text2 = ' '.join(word_list2)
wordcloud.generate(text2)

# %%
plt.figure(figsize=(15,10))
plt.axis("off")
#plt.imshow(wordcloud, interpolation='bilinear')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### 불용어 처리(STOPWORDS)

# %%
from wordcloud import STOPWORDS
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
stop_w = STOPWORDS | ENGLISH_STOP_WORDS | set(["대통령", "국가"])

# %%
wordcloud = WordCloud(background_color='white', max_words=2000,
                      stopwords=stop_w,
                      font_path='C:/Windows/Fnts/malgun.ttf',
                      relative_scaling=0.2)
wordcloud.generate(text2)

# %%
plt.figure(figsize=(15,10))
plt.axis('off')
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %%
from PIL import Image

# %%
img = Image.open("south_korea_4x.png").convert("RGBA")

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
import numpy as np
mask_ar = np.array(img)

# %%
mask_ar.shape
# 4: 점 하나가 4개의 값을 지니고 있음(r, g, b, a(투명도, alpha))
# Out:
# (1124, 720, 4)

# %%
mask_ar.dtype
# Out:
# dtype('uint8')

# %%
wordcloud = WordCloud(background_color='white', max_words=200,
                      stopwords=stop_w,
                      font_path='C:/Windows/Fnts/malgun.ttf',
                      relative_scaling=0.2,
                      mask=mask_ar)
wordcloud.generate(text2)

# %%
plt.figure(figsize=(15,10))
plt.axis('off')
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %% [markdown]
# ### 팔레트 변경

# %%
import random

# %%
def grey_color(word, font_size, position, orientation, random_state=None, **kwargs):
    random.seed(random_state)
    return 'hsl(20, 100%%, %d%%)'%random.randint(50, 100) # 색상 40, 채도 100%
                           # 밝기 값은 랜덤하게 뽑아서 넣어줌

# %%
import numpy as np
from PIL import Image
img = Image.open("south_korea_4x.png").convert("RGBA")
mask_ar = np.array(img)

wordcloud = WordCloud(background_color='black', max_words=200,
                      stopwords=stop_w,
                      font_path='C:/Windows/Fnts/malgun.ttf',
                      relative_scaling=0.2,
                      mask=mask_ar, random_state=42)
wordcloud.generate(text2)
wordcloud.recolor(color_func=grey_color, random_state=3)

#wordcloud.to_file("result2.png")

plt.figure(figsize=(15,10))
plt.axis('off')
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %% [markdown]
# ### 단어 빈도수 계산

# %%
import nltk
words = nltk.Text(text2)

# %%
#from matplotlib import pylab
plt.show = lambda: pylab.savefig('word_count.png')

plt.figure(figsize=(12,6))
words.plot(50) # 50개만
plt.show()
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Administrator\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Administrator\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Administrator\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Administrator\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# # 실습

# %%
import requests
from bs4 import BeautifulSoup

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome("C:\chromedriver")

# %%
from konlpy.tag import Komoran
komoran = Komoran()

# %%
url = "https://www.yonhapnewstv.co.kr/category/news/politics/feed"

# %%
c = requests.get(url)

# %%
soup = BeautifulSoup(c.content, "xml")

# %%
links = soup.select("item > link")

# %%
nouns = list()
for link in links:
    c = requests.get(link.text)
    soup = BeautifulSoup(c.content, "html.parser")
    text = soup.select_one("div.cont-item01 > div.detail").text
    
    nouns.extend(komoran.nouns("%r"%text))
    
text = ' '.join(nouns)

# %%
nouns
# Out:
# ['매체',
#  '문',
#  '대통령',
#  '연설',
#  '반응',
#  '신',
#  '북방',
#  '정책',
#  '비난',
#  '북한',
#  '매체',
#  '문재인',
#  '대통령',
#  '취임',
#  '주년',
#  '연설',
#  '즉각',
#  '반응',
#  '채',
#  '측',
#  '북방',
#  '정책',
#  '비난',
#  '선전',
#  '매체',
#  '통일',
#  '메아리',
#  '남',
#  '측',
#  '코로나',
#  '19',
#  '계기',
#  '북방',
#  '지역',
#  '협력',
#  '확대',
#  '것',
#  '속내',
#  '주장',
#  '북방',
#  '정책',
#  '노태우',
#  '대통령',
#  '시절',
#  '북방',
#  '정책',
#  '재판',
#  '연합뉴스TV',
#  '기사',
#  '문',
#  '제보',
#  '라인',
#  '끝',
#  '정',
#  '총리',
#  '이태원',
#  '검사',
#  '협조',
#  '강도',
#  '대책',
#  '정세균',
#  '국무총리',
#  '이태원',
#  '유흥업소',
#  '방문자',
#  '코로나',
#  '19',
#  '검사',
#  '협조',
#  '강도',
#  '대책',
#  '고려',
#  '수',
#  '경고',
#  '정',
#  '총리',
#  '코로나',
#  '19',
#  '중앙재난안전대책본부',
#  '회의',
#  '모두',
#  '발언',
#  '한시',
#  '방문자',
#  '상당수',
#  '연락',
#  '두절',
#  '검사',
#  '절반',
#  '채',
#  '말',
#  '정',
#  '총리',
#  '진단',
#  '검사',
#  '마무리',
#  '전',
#  '감염',
#  '전파',
#  '위험',
#  '실내',
#  '밀집',
#  '시설',
#  '출입',
#  '자제',
#  '경우',
#  '마스크',
#  '착용',
#  '당부',
# ...

# %%
import numpy as np
from PIL import Image
img = Image.open("alice.png").convert("RGBA")
mask_ar = np.array(img)

# %%
from wordcloud import STOPWORDS
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
stop_w = STOPWORDS | ENGLISH_STOP_WORDS | \
set(["연합뉴스", "연합", "기사문의", "문의", "앵커", "기자", "기사문의", "뉴스", "제보", "닫기",\
    "기사", "라인", "오늘", "시간"])

wordcloud = WordCloud(background_color="white", max_words=1000,
                     stopwords=stop_w,
                     font_path="C:/Windows/Fonts/NanumGothicCoding.ttf",
                     mask=mask_ar,
                     width=1080, height=1686)
wordcloud.generate(text)
#wordcloud.recolor(color_func=)

# %%
plt.figure(figsize=(15,10))
plt.axis('off')
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %% [markdown]
# #### 집에가고싶다

# %%
url = "https://sports.news.naver.com/kbaseball/index.nhn"

# %%
main_url = "https://sports.news.naver.com"
c = requests.get(url)
soup = BeautifulSoup(c.content, "html.parser")
links = list()
for href in soup.find("ul", class_="home_news_list").find_all("li"):
    links.append(main_url+href.find("a")["href"])
    
for link in links:
    print(link)
# Out:
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=047&aid=0002269117
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=477&aid=0000242375
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=410&aid=0000692258
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=022&aid=0003463924
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=014&aid=0004422289
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=109&aid=0004204284
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=076&aid=0003566017
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=477&aid=0000242365
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=410&aid=0000692253
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=396&aid=0000549130
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=076&aid=0003565988
# https://sports.news.naver.com/kbaseball/news/read.nhn?oid=109&aid=0004204267
# ...

# %%
x = "https://sports.news.naver.com/news.nhn?oid=477&aid=0000242375"
driver = webdriver.Chrome("C:\chromedriver")
driver.get(x)
driver.find_element_by_class_name("u_cbox_contents")

#driver.find_element_by_css_selector("div.u_cbox_view_comment > a.u_cbox_btn_view_comment")
#.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-212-67220c35037e> in <module>
#       2 driver = webdriver.Chrome("C:\chromedriver")
#       3 driver.get(x)
# ----> 4 driver.find_element_by_class_name("u_cbox_contents")
#       5
#       6 #driver.find_element_by_css_selector("div.u_cbox_view_comment > a.u_cbox_btn_view_comment")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %% [markdown]
# # 연관분석

# %%
import csv
with open('basket.csv', 'r', encoding='UTF-8') as cf:
    transactions = []
    r = csv.reader(cf)
    for row in r:
        transactions.append(row)

# %%
transactions
# Out:
# [['소주', '콜라', '와인'],
#  ['소주', '오렌지주스', '콜라'],
#  ['콜라', '맥주', '와인'],
#  ['소주', '콜라', '맥주'],
#  ['오렌지주스', '와인']]

# %% [markdown]
# apriori() 연역적 알고리즘(a priori algorithm)을 사용하여 연관 규칙을 알아내는 함수

# %%
from apyori import apriori
rules = apriori(transactions, min_support=0.1, min_confidence=0.1)
results = list(rules)
type(results)
# Out:
# list

# %%
results[0]
# RelationRecord: Namedtuple형식
# frozenset: 수정할 수 없는 set
# Out:
# RelationRecord(items=frozenset({'맥주'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'맥주'}), confidence=0.4, lift=1.0)])

# %%
results[10]
# Out:
# RelationRecord(items=frozenset({'콜라', '소주'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'소주', '콜라'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'소주'}), items_add=frozenset({'콜라'}), confidence=1.0, lift=1.25), OrderedStatistic(items_base=frozenset({'콜라'}), items_add=frozenset({'소주'}), confidence=0.7499999999999999, lift=1.2499999999999998)])

# %%
print("lhs \trhs \t\tsupport\tconfidence\tlift")
for row in results:
    support = row[1]
    ordered_stat = row[2]
    for ordered_item in ordered_stat:
        lhs = [x for x in ordered_item[0]]
        rhs = [x for x in ordered_item[1]]
        confidence = ordered_item[2]
        lift = ordered_item[3]
        print(lhs, " => ", rhs, "\t{:>5.4f}\t{:>5.4f}\t{:>5.4f}".\
             format(support, confidence, lift))
# Out:
# lhs 	rhs 		support	confidence	lift
# []  =>  ['맥주'] 	0.4000	0.4000	1.0000
# []  =>  ['소주'] 	0.6000	0.6000	1.0000
# []  =>  ['오렌지주스'] 	0.4000	0.4000	1.0000
# []  =>  ['와인'] 	0.6000	0.6000	1.0000
# []  =>  ['콜라'] 	0.8000	0.8000	1.0000
# []  =>  ['맥주', '소주'] 	0.2000	0.2000	1.0000
# ['맥주']  =>  ['소주'] 	0.2000	0.5000	0.8333
# ['소주']  =>  ['맥주'] 	0.2000	0.3333	0.8333
# []  =>  ['맥주', '와인'] 	0.2000	0.2000	1.0000
# ['맥주']  =>  ['와인'] 	0.2000	0.5000	0.8333
# ['와인']  =>  ['맥주'] 	0.2000	0.3333	0.8333
# []  =>  ['맥주', '콜라'] 	0.4000	0.4000	1.0000
# ['맥주']  =>  ['콜라'] 	0.4000	1.0000	1.2500
# ['콜라']  =>  ['맥주'] 	0.4000	0.5000	1.2500
# []  =>  ['소주', '오렌지주스'] 	0.2000	0.2000	1.0000
# ['소주']  =>  ['오렌지주스'] 	0.2000	0.3333	0.8333
# ['오렌지주스']  =>  ['소주'] 	0.2000	0.5000	0.8333
# []  =>  ['소주', '와인'] 	0.2000	0.2000	1.0000
# ['소주']  =>  ['와인'] 	0.2000	0.3333	0.5556
# ['와인']  =>  ['소주'] 	0.2000	0.3333	0.5556
# []  =>  ['소주', '콜라'] 	0.6000	0.6000	1.0000
# ['소주']  =>  ['콜라'] 	0.6000	1.0000	1.2500
# ...

# %%
import requests
rss_url = "http://fs.jtbc.joins.com/RSS/economy.xml"
jtbc_economy = requests.get(rss_url)

# %%
from bs4 import BeautifulSoup
economy_news_list = BeautifulSoup(jtbc_economy.content, "xml")
link_list = economy_news_list.select("item > link")

# %%
len(link_list)
# Out:
# 20

# %%
link_list[0].text
# Out:
# 'http://news.jtbc.joins.com/article/article.aspx?news_id=NB11949632'

# %%
from konlpy.tag import Kkma
kkma = Kkma()

news = [] #transaction
for link in link_list:
    news_url = link.text
    news_response = requests.get(news_url)
    news_soup = BeautifulSoup(news_response.content, "html.parser")
    news_content = news_soup.select_one("#articlebody > .article_content")
    news.append(list(filter(lambda word: len(word)>1,
                           kkma.nouns(news_content.text))))

# %%
from apyori import apriori
rules = apriori(news, min_support=0.2, min_confidence=0.2)
results = list(rules)

import pandas as pd
result_df = pd.DataFrame(None,
                        columns = ["lhs", "rhs", "support",
                                  "confidence", "lift"])
index = 0
for row in results:
    support = row[1]
    ordered_stat = row[2]
    for ordered_item in ordered_stat:
        lhs = " ".join(x.strip() for x in ordered_item[0])
        rhs = " ".join(x.strip() for x in ordered_item[1])
        confidence = ordered_item[2]
        lift = ordered_item[3]
        result_df.loc[index] = [lhs, rhs, support, confidence, lift]
        index = index+1

# %%
result_df.loc[result_df.lhs==""].sort_values(by=["support"],
                                            ascending=False)

# %%
result_df.loc[(result_df.lhs.str.contains("")) &
             (result_df.rhs=="")].sort_values(by=["lift"],
                                             ascending=False)

# %%
result_df.loc[(result_df.lhs.str.contains("")) &
             (result_df.rhs=="")].sort_values(by=["support"],
                                             ascending=False)
